# 37992      900 2012-04-05 00:00:00  3900.0          0.25
# 37993      900 2012-04-05 00:15:00  3000.0          0.25
# 37994      900 2012-04-05 00:30:00  3000.0          0.25
# 37995      900 2012-04-05 00:45:00  3000.0          0.25
# 37996      900 2012-04-05 01:00:00  2700.0          0.25
# 37997      900 2012-04-05 01:15:00  3000.0          0.25
# 37998      900 2012-04-05 01:30:00  2700.0          0.25
# 37999      900 2012-04-05 01:45:00  2400.0          0.25
# 38000      900 2012-04-05 02:00:00  2400.0          0.25
# 38001      900 2012-04-05 02:15:00  2700.0          0.25
# 38002      900 2012-04-05 02:30:00  2700.0          0.25
# 38003      900 2012-04-05 02:45:00  2400.0          0.25
# 38004      900 2012-04-05 03:00:00  2400.0          0.25
# 38005      900 2012-04-05 03:15:00  2700.0          0.25
# 38006      900 2012-04-05 03:30:00  3000.0          0.25
# 38007      900 2012-04-05 03:45:00  3000.0          0.25
#
# [38008 rows x 4 columns]

# %%
read_clipboard = False
if read_clipboard == True:
    simple_load = pd.read_clipboard()
    simple_load.to_pickle("simple_load_1d.pkl")

# %%
import pickle
simple_load = pd.read_pickle("simple_load_1d.pkl")
#simple_load = pd.read_clipboard()
simple_load.value.plot()

# %%
env.load.initialize(simple_load)
env.fit_load_to_space()

# %%
# Show the possible action mapping the agent can take
env.action_mapping
# Out:
# {0: -1000.0, 1: -500.0, 2: 0.0, 3: 500.0, 4: 1000.0}

# %%
print(env.observation_space.low)
print("to")
print(env.observation_space.high)
# Out:
# [   0.    0. 1000. 1000.]
# to
# [   24. 10000.  5000.  6000.]

# %%
# Set how to structure the environment. 'count_days' will generate the a single day as an episode. THe number of days
# given indicates how many differnet days to use.
# This needs to be changed so that it generates LONGER episodes, not DIFFERENT episodes, but this hasn't been done yet.
env.episode_type = 'count_days'
env.run_N_episodes = 1

# %%
# Get the do-nothing value for taking no action
def dict_key_by_val(d, val):
    for k in d.keys():
        if d[k] == val:
            return k
    raise ValueError("value not found in dictionary")
    
act0 = dict_key_by_val(env.action_mapping, 0)
act0
# Out:
# 2

# %%
''' Set up the agent and the discretizer.'''
from batterydispatch.agent.agents import MonteCarloAgent
from batterydispatch.agent.discretizers import Box_Discretizer

from batterydispatch.agent.policies import do_nothing
agent = MonteCarloAgent()
agent.set_policy(do_nothing, {'do_nothing_action': act0})

# Note, you can change the size of the state sapce by changing the number of buckets, below
agent.set_discretizer(Box_Discretizer(env.observation_space, N=[4, 4, 8, 10]))
agent.actions = env.action_space
agent.learning_rate = 0.05 # used for the updates of the Q estimates
agent.subtype = 'on-policy' # Setup the MC agent for off-policy learning

# %%
agent.discretizer.buckets
# Out:
# [array([ 6., 12., 18., 24.]),
#  array([ 2500.5,  5001. ,  7501.5, 10002. ]),
#  array([1500.25, 2000.5 , 2500.75, 3001.  , 3501.25, 4001.5 , 4501.75,
#         5002.  ]),
#  array([1500.2, 2000.4, 2500.6, 3000.8, 3501. , 4001.2, 4501.4, 5001.6,
#         5501.8, 6002. ])]

# %% [markdown]
# ## Plot the day of data that we will be trying to learn from

# %%
done = False
state = env.reset()
i = 0
while not done:
    i+=1
    action = agent.get_action(state, env.action_space, 0)
    _,reward,done, details = env.step(action)

from matplotlib import pyplot as plt
plt.plot(env.grid_flow.net_flow)
try:
    print(list(env.grid_flow.start_date)[0])
except:
    pass
print(i)
print(reward)
default_reward = reward
plt.show()
# Out:
# c:\users\administrator\pycharmprojects\gym-battery\gym_battery\envs\battery_env.py:152: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# 86  3000.0             0.0              0.0  (21.0, 0.0, 3000.0, 5000.0)
# 87  3000.0             0.0              0.0  (21.0, 0.0, 3000.0, 5000.0)
# 88  3000.0             0.0              0.0  (22.0, 0.0, 3000.0, 5000.0)
# 89  3000.0             0.0              0.0  (22.0, 0.0, 3000.0, 5000.0)
# 90  3000.0             0.0              0.0  (22.0, 0.0, 3000.0, 5000.0)
# 91  3000.0             0.0              0.0  (22.0, 0.0, 3000.0, 5000.0)
# 92  3000.0             0.0              0.0  (23.0, 0.0, 3000.0, 5000.0)
# 93  3000.0             0.0              0.0  (23.0, 0.0, 3000.0, 5000.0)
# 94  3000.0             0.0              0.0  (23.0, 0.0, 3000.0, 5000.0)
# 95  3000.0             0.0              0.0  (23.0, 0.0, 3000.0, 5000.0)
#
# [96 rows x 10 columns]

# %%
# We then initialize the agent state-action estimates, based on the original billing period.
# We also give the do_nothing action a small bonus of 100, in order to prevent the agent from arbitrarily taking action.
agent.initialize_state_actions(new_default=default_reward,
                              do_nothing_action = act0,
                              do_nothing_bonus = 100)

# %% [markdown]
# ## Set up the function to run the episodes, and run episodes until convergence.

# %%
# This function runs the actual episodes, repeatedly, until policy converges.

from IPython.display import clear_output
# initial state
from batterydispatch.agent.agents import PolicyConvergedError
def run_to_convergence(random_charge = True):
    possible_actions = list(env.action_mapping.keys())
    converged=False
    done=False
    i = 0
    eps = 0
    while not converged:
        state = env.reset(random_charge=random_charge)

        i += 1
        eps+=1
        if i > 30:
            i = 0
            clear_output()

        while not done:
            action = agent.get_action(state, possible_actions, 0.25)
            #print(action)
            old_state = state.copy()
            state, reward, done, details = env.step(action)
            
            agent.observe_sars(old_state, action, reward, state)
        try:
            agent.end_episode(reward)
        except PolicyConvergedError:
            converged = True

        try:
            new_demand = max(env.grid_flow.net_flow)
            orig_demand = max(env.grid_flow.load)
        except AttributeError:
            new_demand = "???"
            orig_demand = "???"

        done = False


        print(f"Current reward of {int(reward)} / {int(default_reward)}, {new_demand} / {orig_demand}, patience={agent.patience_counter}")
        #converged = agent.check_policy_convergence(False)
    print("Converged!")
    return eps

# %%
# We then set the final parameters guiding the episodes: The agents proclivity for random actions, 
# the number of episodes without a policy change before we can say we've converge.
agent.set_greedy_policy(eta=0.05)
agent.patience = 100

# %%
agent.learning_rate = 0.075

# %%
reward=500000
while abs(reward) > 413000:
    state = env.reset(random_charge=False)
    possible_actions = list(env.action_mapping.keys())
    done=False
    while not done:
        action = agent.get_action(state, possible_actions, 0.25)
        #print(action)
        old_state = state.copy()
        state, reward, done, details = env.step(action)

        agent.observe_sars(old_state, action, reward, state)
    try:
        agent.end_episode(reward)
    except:
        converged = True

    try:
        new_demand = max(env.grid_flow.net_flow)
        orig_demand = max(env.grid_flow.load)
    except AttributeError:
        new_demand = "???"
        orig_demand = "???"



    print(f"Current reward of {int(reward)} / {int(default_reward)}, {new_demand} / {orig_demand}, patience={agent.patience_counter}")

    print("")
    #converged = agent.check_policy_convergence(False)
# Out:
# c:\users\administrator\pycharmprojects\gym-battery\gym_battery\envs\battery_env.py:152: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   self.grid_flow.set_value(self.step_ix, 'state', tuple(self.state))
# Current reward of -416493 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=4
#
# Current reward of -416493 / -416388, 5000.0 / 5000.0, patience=5
#
# Current reward of -416493 / -416388, 5000.0 / 5000.0, patience=6
#
# Current reward of -416598 / -416388, 5000.0 / 5000.0, patience=7
#
# Current reward of -416493 / -416388, 5000.0 / 5000.0, patience=8
#
# Current reward of -428224 / -416388, 5500.0 / 5000.0, patience=1
#
# Current reward of -416598 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -416598 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416598 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416493 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -416493 / -416388, 5000.0 / 5000.0, patience=4
#
# Current reward of -416283 / -416388, 5000.0 / 5000.0, patience=5
#
# Current reward of -416914 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416493 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -416703 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416598 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416493 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -444594 / -416388, 5800.0 / 5000.0, patience=1
#
# Current reward of -414704 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -455428 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -440417 / -416388, 5500.0 / 5000.0, patience=1
#
# Current reward of -438662 / -416388, 5500.0 / 5000.0, patience=1
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=4
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=5
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=6
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=7
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=8
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=9
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=10
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=11
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=12
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=13
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=14
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=15
#
# Current reward of -438985 / -416388, 6000.0 / 5000.0, patience=1
#
# Current reward of -417484 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -422951 / -416388, 5300.0 / 5000.0, patience=1
#
# Current reward of -416936 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -426518 / -416388, 5500.0 / 5000.0, patience=1
#
# Current reward of -421611 / -416388, 5250.0 / 5000.0, patience=1
#
# Current reward of -418071 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -413059 / -416388, 4750.0 / 5000.0, patience=2
#
# Current reward of -418071 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -424439 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -418177 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -418177 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=4
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=5
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=6
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=7
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=8
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=9
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=10
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=11
#
# Current reward of -426623 / -416388, 5500.0 / 5000.0, patience=1
#
# Current reward of -418177 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -428593 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -416388 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -423720 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -427352 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -427707 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -415756 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -415546 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -415967 / -416388, 5000.0 / 5000.0, patience=4
#
# Current reward of -421400 / -416388, 5250.0 / 5000.0, patience=1
#
# Current reward of -435912 / -416388, 6000.0 / 5000.0, patience=1
#
# Current reward of -419124 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -417650 / -416388, 5000.0 / 5000.0, patience=2
#
# Current reward of -417650 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -417440 / -416388, 5000.0 / 5000.0, patience=4
#
# Current reward of -418071 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -417650 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -417650 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -417861 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -417650 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -443079 / -416388, 5000.0 / 5000.0, patience=1
#
# Current reward of -414331 / -416388, 4500.0 / 5000.0, patience=2
#
# Current reward of -416914 / -416388, 5000.0 / 5000.0, patience=3
#
# Current reward of -415976 / -416388, 4500.0 / 5000.0, patience=4
#
# Current reward of -416809 / -416388, 5000.0 / 5000.0, patience=5
#
# Current reward of -412476 / -416388, 4500.0 / 5000.0, patience=6

# %%
# %%time
agent.patience_counter = 0

eps = run_to_convergence(random_charge = False)
eps
# Out:
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=7
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=8
# Current reward of -408046 / -416388, 4500.0 / 5000.0, patience=9
# Current reward of -407941 / -416388, 4500.0 / 5000.0, patience=10
# Current reward of -408152 / -416388, 4500.0 / 5000.0, patience=11
# Current reward of -418282 / -416388, 5000.0 / 5000.0, patience=1
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=2
# Current reward of -408046 / -416388, 4500.0 / 5000.0, patience=3
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=4
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=5
# Current reward of -414272 / -416388, 4800.0 / 5000.0, patience=6
# Current reward of -419251 / -416388, 5000.0 / 5000.0, patience=1
# Current reward of -407310 / -416388, 4500.0 / 5000.0, patience=2
# Current reward of -407310 / -416388, 4500.0 / 5000.0, patience=3
# Current reward of -425992 / -416388, 5500.0 / 5000.0, patience=1
# Current reward of -427675 / -416388, 5500.0 / 5000.0, patience=1
# Current reward of -408257 / -416388, 4500.0 / 5000.0, patience=2
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=3
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=4
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=5
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=6
# Current reward of -407836 / -416388, 4500.0 / 5000.0, patience=7

# %%
Qs = pd.DataFrame.from_dict(agent.S_A_values, orient='index')
Qs.to_clipboard()

# %%
counts = pd.DataFrame.from_dict(agent.S_A_frequency, orient='index')
counts.to_clipboard

# %%
print(f"The agent converged after {eps} episodes")

# %% [markdown]
# Agent has taken between 10 and 30 minutes, and between 700 and 2262 episodes, to converge on day 1. Optimal policy:
# Current reward of -397414.125 / -406791.825, 5600.0 / 6000.0, patience=21
#
# For 2 days, agent took 5 hours 8 minutes, and converged after 21200 episodes.

# %% [markdown]
# ## Then we allow the agent to take entirely greedy actions and run the algorithm to see how much the agent learned.

# %%
agent.set_greedy_policy(eta=0)
    
state = env.reset(random_charge=False)
done = False
while not done:
    action = agent.get_action(state, list(env.action_mapping.keys()), 0.25)
    #print(state)
    #action = int(input("action:"))

    #print(action)
    state, reward, done, details = env.step(action)

try:
    new_demand = max(env.grid_flow.net_flow)
    orig_demand = max(env.grid_flow.load)
except AttributeError:
    new_demand = "???"
    orig_demand = "???"
    
    env.grid_flow['final_reward'] = reward
    env.grid_flow['original_reward'] = default_reward


print(f"Current reward of {reward} / {default_reward}, {new_demand} / {orig_demand}, patience={agent.patience_counter}")

# %%
# If desired we can output the results to the clipboard for further analysis
env.grid_flow.to_clipboard()

# %%
env.reset()

# %%
env.reset()

# %%
def EG():
    raise StopIterationError:

# %%
def gen():
    yield from ()
    
g = gen()
next(g)

# %%
freq = agent.S_A_frequency.copy()
freq.pop(tuple('terminal'))
freq = pd.DataFrame.from_dict(freq, orient='index')

# %%
val = agent.S_A_values.copy()
val.pop(tuple('terminal'))
val = pd.DataFrame.from_dict(val, orient='index')

# %%
val = val.reset_index()
val['state'] = [[i.level_0, i.level_1, i.level_2, i.level_3] for ix, i in val.iterrows()]
val = val.rename(columns={"state": "agent_state"})
val.index = val.agent_state
val = val.drop(columns=['level_0', 'level_1', 'level_2', 'level_3', 'agent_state'])
val.index = [tuple(x) for x in val.index]
val.head()
# Out:
#                                                         0              1  \
# (6.0, 2500.5, 1500.25, 1500.2)             -422464.378293 -419336.515843
# (6.0, 2500.5, 1500.25, 2000.4)             -419754.807830 -419704.597906
# (6.0, 2500.5, 1500.25, 2500.6000000000004) -418804.383719 -418310.042680
# (6.0, 2500.5, 1500.25, 3000.8)             -416388.158750 -416388.158750
# (6.0, 2500.5, 1500.25, 3501.0)             -416388.158750 -416388.158750
#
#                                                         2              3  \
# (6.0, 2500.5, 1500.25, 1500.2)             -419767.077464 -421341.357727
# (6.0, 2500.5, 1500.25, 2000.4)             -419740.048609 -418027.378656
# (6.0, 2500.5, 1500.25, 2500.6000000000004) -418095.321219 -417951.367277
# (6.0, 2500.5, 1500.25, 3000.8)             -416288.158750 -416388.158750
# (6.0, 2500.5, 1500.25, 3501.0)             -416288.158750 -416388.158750
#
#                                                         4
# (6.0, 2500.5, 1500.25, 1500.2)             -421764.440315
# (6.0, 2500.5, 1500.25, 2000.4)             -419517.306906
# (6.0, 2500.5, 1500.25, 2500.6000000000004) -418026.651582
# (6.0, 2500.5, 1500.25, 3000.8)             -416388.158750
# (6.0, 2500.5, 1500.25, 3501.0)             -416388.158750

# %%
DF = env.grid_flow.copy()
DF['agent_state'] = [agent.discretize_space(np.array(s)) for s in DF.state]
DF.agent_state = [tuple(x) for x in DF.agent_state]
DF.head()
# Out:
#    duration               start   value  duration_hrs  start_date  net_flow  \
# 0       900 2011-03-07 00:00:00  1000.0          0.25  2011-03-07    1500.0
# 1       900 2011-03-07 00:15:00  1000.0          0.25  2011-03-07    1500.0
# 2       900 2011-03-07 00:30:00  1000.0          0.25  2011-03-07    1500.0
# 3       900 2011-03-07 00:45:00  1000.0          0.25  2011-03-07    1500.0
# 4       900 2011-03-07 01:00:00  1000.0          0.25  2011-03-07     500.0
#
#      load  battery_action  state_of_charge                         state  \
# 0  1000.0          -500.0            125.0    (0.0, 0.0, 1000.0, 1000.0)
# 1  1000.0          -500.0            250.0  (0.0, 125.0, 1000.0, 1500.0)
# 2  1000.0          -500.0            375.0  (0.0, 250.0, 1000.0, 1500.0)
# 3  1000.0          -500.0            500.0  (0.0, 375.0, 1000.0, 1500.0)
# 4  1000.0           500.0            375.0  (1.0, 500.0, 1000.0, 1500.0)
#
#                       agent_state
# 0  (6.0, 2500.5, 1500.25, 1500.2)
# 1  (6.0, 2500.5, 1500.25, 1500.2)
# 2  (6.0, 2500.5, 1500.25, 1500.2)
# 3  (6.0, 2500.5, 1500.25, 1500.2)
# 4  (6.0, 2500.5, 1500.25, 1500.2)

# %%
DF.join(val, on='agent_state').to_clipboard()

# %%
env.load.DF
