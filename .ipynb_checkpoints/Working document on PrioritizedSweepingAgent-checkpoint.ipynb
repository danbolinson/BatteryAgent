# %%
import gym
import gym_battery

# %%
env = gym.make('gym_battery:battery-v0')

# %%
env.episode_type = env.episode_types[0]
env.episode_type
# Out:
# 'first_day'

# %%
def dict_key_by_val(d, val):
    for k in d.keys():
        if d[k] == val:
            return k
    raise ValueError("value not found in dictionary")

# %%
act0 = dict_key_by_val(env.action_mapping, 0)
act0
# Out:
# 2

# %%
from batterydispatch.agent.agents import MonteCarloAgent
from batterydispatch.agent.discretizers import Box_Discretizer

from batterydispatch.agent.policies import do_nothing
#MCAgent.initialize_state_actions(MCAgent.discretizer.list_all_states, env.action_space, default_val)
agent = MonteCarloAgent()
agent.set_policy(do_nothing, {'do_nothing_action': act0})
agent.set_discretizer(Box_Discretizer(env.observation_space, N=[6, 4, 25, 25]))
agent.learning_rate = 0.05

# %%
done = False
state = env.reset()
i = 0
while not done:
    i+=1
    action = agent.get_action(state, env.action_space, 0)
    _,reward,done, details = env.step(action)

from matplotlib import pyplot as plt
plt.plot(env.grid_flow.net_flow)
print(i)
print(reward)
default_reward = reward
plt.show()
# Out:
# 96
# -430014.0

# %%
if input("override default reward?").lower() == "y":
    default_reward += 1000
# Out:
# override default reward?n

# %%
agent.initialize_state_actions(agent.discretizer.list_all_states(), 
                               list(range(env.action_space.n)), 
                               default=default_reward,
                              do_nothing_action = act0,
                              do_nothing_bonus = 100)

# %%
agent.S_A_values
# Out:
# {(0.0, 0.0, 300.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 300.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 936.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 1572.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2208.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 2844.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 3480.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4116.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 4752.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 5388.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6024.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 6660.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7296.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 7932.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 8568.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9204.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 9840.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 10476.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 0.0, 11112.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
# ...
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6024.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 6660.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7296.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 7932.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 8568.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, -1700.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, -904.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, -108.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 688.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 1484.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 2280.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 3076.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 3872.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 4668.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 5464.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 6260.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 7056.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 7852.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 8648.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 9444.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 10240.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 11036.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 11832.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 12628.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 13424.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 14220.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 15016.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 15812.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 16608.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  (0.0, 2500.0, 9204.0, 17404.0): {0: -430014.0,
#   1: -430014.0,
#   2: -429914.0,
#   3: -430014.0,
#   4: -430014.0},
#  ...}

# %%
from IPython.display import clear_output
# initial state
from batterydispatch.agent.agents import PolicyConvergedError
def run_to_convergence(random_charge = True):
    possible_actions = list(env.action_mapping.keys())
    converged=False
    done=False
    i = 0
    while not converged:
        state = env.reset(random_charge=random_charge)

        i += 1
        if i > 50:
            i = 0
            clear_output()

        while not done:
            action = agent.get_action(state, possible_actions, 0.25)
            #print(action)
            old_state = state.copy()
            state, reward, done, details = env.step(action)
            
            #agent.observe_sars(old_state, action, reward, state)
        try:
            agent.end_episode(reward)
        except PolicyConvergedError:
            converged = True

        try:
            new_demand = max(env.grid_flow.net_flow)
            orig_demand = max(env.grid_flow.load)
        except AttributeError:
            new_demand = "???"
            orig_demand = "???"

        done = False


        print(f"Current reward of {int(reward)} / {int(default_reward)}, {new_demand} / {orig_demand}, patience={agent.patience_counter}")
        #converged = agent.check_policy_convergence(False)
    print("Converged!")

# %%
agent.set_greedy_policy(eta=0.075)
agent.patience = 20
agent.subtype = 'off-policy'
agent.patience_counter = 0

# %%
# %%time
run_to_convergence(random_charge = True)
# Out:
# Current reward of -448158 / -430014, 6500.0 / 5700.0, patience=2
# Current reward of -444215 / -430014, 6400.0 / 5700.0, patience=3
# Current reward of -436083 / -430014, 5700.0 / 5700.0, patience=4
# Current reward of -469850 / -430014, 7700.0 / 5700.0, patience=True
# Current reward of -421439 / -430014, 5100.0 / 5700.0, patience=True
# Current reward of -448706 / -430014, 6700.0 / 5700.0, patience=True
# Current reward of -429750 / -430014, 5700.0 / 5700.0, patience=True
# Current reward of -439243 / -430014, 6100.0 / 5700.0, patience=2
# Current reward of -421220 / -430014, 5100.0 / 5700.0, patience=True
# Current reward of -428698 / -430014, 5700.0 / 5700.0, patience=2
# Current reward of -426493 / -430014, 5300.0 / 5700.0, patience=3
# Current reward of -420132 / -430014, 5100.0 / 5700.0, patience=True
# Current reward of -450011 / -430014, 6700.0 / 5700.0, patience=2
# Current reward of -424000 / -430014, 5100.0 / 5700.0, patience=3
# Current reward of -473780 / -430014, 7700.0 / 5700.0, patience=True
# Current reward of -419711 / -430014, 5100.0 / 5700.0, patience=True
# Current reward of -419448 / -430014, 5100.0 / 5700.0, patience=2
# Current reward of -443619 / -430014, 6400.0 / 5700.0, patience=3
# Current reward of -432497 / -430014, 5900.0 / 5700.0, patience=4
# Current reward of -417729 / -430014, 5100.0 / 5700.0, patience=True
# Current reward of -451428 / -430014, 6800.0 / 5700.0, patience=2
# Current reward of -477122 / -430014, 6700.0 / 5700.0, patience=True
# Current reward of -447263 / -430014, 6500.0 / 5700.0, patience=True
# Current reward of -456768 / -430014, 7100.0 / 5700.0, patience=2
# Current reward of -503295 / -430014, 7700.0 / 5700.0, patience=3
# Current reward of -491377 / -430014, 7400.0 / 5700.0, patience=True
# Current reward of -438933 / -430014, 6200.0 / 5700.0, patience=True
# Current reward of -456406 / -430014, 5700.0 / 5700.0, patience=True
# Current reward of -422903 / -430014, 5100.0 / 5700.0, patience=2
# Current reward of -501988 / -430014, 7700.0 / 5700.0, patience=True
# Current reward of -444948 / -430014, 6500.0 / 5700.0, patience=True
# Current reward of -490603 / -430014, 7700.0 / 5700.0, patience=True
# Current reward of -431219 / -430014, 5100.0 / 5700.0, patience=2
# Current reward of -486419 / -430014, 7700.0 / 5700.0, patience=True
# Current reward of -438681 / -430014, 6200.0 / 5700.0, patience=True
# Current reward of -425736 / -430014, 5100.0 / 5700.0, patience=True
# Current reward of -437359 / -430014, 5800.0 / 5700.0, patience=True
# Current reward of -422693 / -430014, 5100.0 / 5700.0, patience=2
# Current reward of -442943 / -430014, 6400.0 / 5700.0, patience=3
# Current reward of -424219 / -430014, 5100.0 / 5700.0, patience=True
# Current reward of -426703 / -430014, 5300.0 / 5700.0, patience=True
# Current reward of -430381 / -430014, 5700.0 / 5700.0, patience=True
# Current reward of -433087 / -430014, 5900.0 / 5700.0, patience=2
# Current reward of -437560 / -430014, 6100.0 / 5700.0, patience=True

# %%
agent.set_greedy_policy(eta=0.075)
agent.patience = 20
agent.subtype = 'off-policy'
agent.patience_counter = 0

# %%
agent.discretizer.buckets
# Out:
# [array([ 0.,  4.,  8., 12., 16., 20.]),
#  array([   0., 2500., 5000., 7500.]),
#  array([  300.,  1095.,  1890.,  2685.,  3480.,  4275.,  5070.,  5865.,
#          6660.,  7455.,  8250.,  9045.,  9840., 10635., 11430., 12225.,
#         13020., 13815., 14610., 15405.]),
#  array([-1700.,  -705.,   290.,  1285.,  2280.,  3275.,  4270.,  5265.,
#          6260.,  7255.,  8250.,  9245., 10240., 11235., 12230., 13225.,
#         14220., 15215., 16210., 17205.])]

# %%
run_to_convergence(random_charge = True)
# Out:
# Current reward of -420303 / -430014, 5300.0 / 5700.0, patience=1
# Current reward of -420514 / -430014, 5300.0 / 5700.0, patience=2
# Current reward of -419207 / -430014, 5300.0 / 5700.0, patience=True
# Current reward of -467589 / -430014, 7400.0 / 5700.0, patience=2
# Current reward of -441750 / -430014, 6500.0 / 5700.0, patience=3
# Current reward of -470879 / -430014, 7400.0 / 5700.0, patience=4
# Current reward of -420049 / -430014, 5300.0 / 5700.0, patience=5
# Current reward of -428534 / -430014, 5700.0 / 5700.0, patience=6
# Current reward of -416668 / -430014, 5100.0 / 5700.0, patience=True
# Current reward of -420536 / -430014, 5400.0 / 5700.0, patience=2
# Current reward of -418742 / -430014, 5300.0 / 5700.0, patience=3
# Current reward of -419417 / -430014, 5300.0 / 5700.0, patience=4
# Current reward of -419628 / -430014, 5300.0 / 5700.0, patience=5
# Current reward of -421420 / -430014, 5400.0 / 5700.0, patience=True
# Current reward of -426551 / -430014, 5700.0 / 5700.0, patience=2
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# c:\users\administrator\pycharmprojects\gym-battery\gym_battery\envs\battery_env.py in step(self, action)
#     109         try:
# --> 110             self.step_ix, self.step_row = next(self.episode_step_generator)
#     111             self.state = np.array([self.step_row.start.hour,
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-74bc1478034c> in <module>()
# ----> 1 run_to_convergence(random_charge = True)
#
# <ipython-input-11-b143f156d9ae> in run_to_convergence(random_charge)
#      19             #print(action)
#      20             old_state = state.copy()
# ---> 21             state, reward, done, details = env.step(action)
#      22
#      23             #agent.observe_sars(old_state, action, reward, state)
#
# c:\users\administrator\pycharmprojects\gym-battery\gym_battery\envs\battery_env.py in step(self, action)
#     116             episode_over = True
#     117             demand_charge = self.tariff.calculate_demand_charge(self.grid_flow, 'net_flow')
# --> 118             energy_charge = self.tariff.calculate_energy_charge(self.grid_flow, 'net_flow') * \
#     119                             (1 if 'month' in self.episode_type else 30)
#     120             reward -= (demand_charge + energy_charge)
#
# c:\users\administrator\pycharmprojects\gym-battery\gym_battery\envs\env_assets\Tariff.py in calculate_energy_charge(self, bill_month, value)
#      42            Takes: Bill month should be given as a dataframe with value, timestamp(start) and duration_hrs columns.
#      43            Returns: bill in dollars.'''
# ---> 44         return np.sum([self.calculate_energy_step(x, value) for i, x in bill_month.iterrows()])
#      45
#      46     def calculate_energy_step(self, t, value='value'):
#
# c:\users\administrator\pycharmprojects\gym-battery\gym_battery\envs\env_assets\Tariff.py in <listcomp>(.0)
#      42            Takes: Bill month should be given as a dataframe with value, timestamp(start) and duration_hrs columns.
#      43            Returns: bill in dollars.'''
# ---> 44         return np.sum([self.calculate_energy_step(x, value) for i, x in bill_month.iterrows()])
#      45
#      46     def calculate_energy_step(self, t, value='value'):
#
# c:\users\administrator\pycharmprojects\gym-battery\gym_battery\envs\env_assets\Tariff.py in calculate_energy_step(self, t, value)
#      53             rate = self.ENERGY_OFFPEAK
#      54
# ---> 55         return t.duration_hrs * t[value] * rate
#      56
#      57     def calculate_demand_charge(self, bill_month, value='value'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     864
#     865     def __getitem__(self, key):
# --> 866         key = com.apply_if_callable(key, self)
#     867         try:
#     868             result = self.index.get_value(self, key)
#
# KeyboardInterrupt:

# %%
agent.set_greedy_policy(eta=0)

state = env.reset()
done = False
while not done:
    action = agent.get_action(state, list(env.action_mapping.keys()), 0.25)
    #print(action)
    state, reward, done, details = env.step(action)

try:
    new_demand = max(env.grid_flow.net_flow)
    orig_demand = max(env.grid_flow.load)
except AttributeError:
    new_demand = "???"
    orig_demand = "???"


print(f"Current reward of {reward} / {default_reward}, {new_demand} / {orig_demand}, patience={agent.patience_counter}")
# Out:
# Current reward of -425078.55 / -430014.0, 5700.0 / 5700.0, patience=21

# %%
state = env.observation_space.sample()
state

# %%
agent.discretize_space(state)

# %%
print(agent.discretizer.buckets)
for i, s in enumerate(state):
    print(f"{s}, {i}")
    j = np.digitize(s, agent.discretizer.buckets[i], right=True)-1
    print(j)
    print(agent.discretizer.buckets[i][j])

# %%
1 + True

# %% [raw]
# WHERE I ENDED
#     I THINK the agent is ready to interact with the environment. Will be important to first set the state space, which right now requires calling MCAgent.initialize_state_actions(MCAgent.discretizer.list_all_states, env.action_space, default_val)
#
# Running the episode should be simple:
# - Set up the environment
# - Set up the agent, including the Discretizer
# - Alternatively the discretizer could live outside the agent?! but right now not implemented that way.
# - Then reset the environment, retrieving the first state;
# - While the episode is not over:
#     - Feed the state to the Agent, and retrieve the action;
#     - Feed the action to the environment and retrieve 4 results
#
# Reiterate as much as needed/wanted
